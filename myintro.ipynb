# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/conveneml/supervised/blob/main/myintro.ipynb)

# %% [markdown]
# ## Stuff to do before starting
#
# Sign up to github at github.com
# Sign up to kaggle at kaggle.com

# %%
# !pip install --upgrade pandas_datareader
# Out:
# ...
#      |████████████████████████████████| 109 kB 4.1 MB/s
# ...
#   Attempting uninstall: pandas-datareader
#     Found existing installation: pandas-datareader 0.9.0
#     Uninstalling pandas-datareader-0.9.0:
#       Successfully uninstalled pandas-datareader-0.9.0
# ...

# %%
# Load libraries
import pandas as pd
from matplotlib import pyplot

#Load CSV files with Pandas from local file [disabled - use when running notebook on local machine]
#from pandas import read_csv
#filename = '~/Downloads/diabetes.csv'
#dataset = read_csv(filename)


#Load file from URL
from pandas import read_csv
url = 'https://raw.githubusercontent.com/conveneml/supervised/main/diabetes.csv'
names = ['age', 'class']
dataset = read_csv(url, names=names)


#Load file using pandas_datareader from the Yahoo Finance and FRED websites
import pandas_datareader.data as web
stk_tickers = ['MSFT', 'IBM', 'GOOGL']
ccy_tickers = ['DEXJPUS', 'DEXUSUK']
idx_tickers = ['SP500', 'DJIA', 'VIXCLS']
stk_data = web.DataReader(stk_tickers, 'yahoo')
ccy_data = web.DataReader(ccy_tickers, 'fred')
idx_data = web.DataReader(idx_tickers, 'fred')

# %%
stk_data
# Out:
# Attributes   Adj Close              ...      Volume
# Symbols           MSFT         IBM  ...         IBM      GOOGL
# Date                                ...
# 2017-01-19   57.925175  126.790802  ...   7283716.0  1070500.0
# 2017-01-20   58.334282  129.633530  ...  13273740.0  1306200.0
# 2017-01-23   58.538830  129.998413  ...   5730197.0  2457400.0
# 2017-01-24   59.059505  133.700027  ...   7272210.0  1688400.0
# 2017-01-25   59.208271  135.516647  ...   6194935.0  1655400.0
# ...                ...         ...  ...         ...        ...
# 2022-01-11  314.980011  132.869995  ...  11105300.0  1436500.0
# 2022-01-12  318.269989  133.589996  ...   5352000.0  1305400.0
# 2022-01-13  304.799988  134.759995  ...   4868300.0  1571800.0
# 2022-01-14  310.200012  134.210007  ...   5309200.0  1482100.0
# 2022-01-18  302.459991  132.899994  ...   3323636.0  1267455.0
#
# [1259 rows x 18 columns]
